# %% [markdown]
# # EDA
#
# Offline exploratory analysis for the mapped UPI fraud datasets.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import load_all_datasets, generate_schema_reports, load_and_map_all

# %%
datasets = load_all_datasets(PROJECT_ROOT / 'data' / 'raw')
generate_schema_reports(datasets)

# %%
df = load_and_map_all(PROJECT_ROOT / 'data' / 'raw')
df.head()

# %%
df.describe(include='all')
