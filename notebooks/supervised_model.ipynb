# %% [markdown]
# # Supervised Fraud Detection
#
# Train XGBoost and Random Forest and inspect metrics.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import load_and_map_all
from src.supervised_model import train_supervised_models

# %%
df = load_and_map_all(PROJECT_ROOT / 'data' / 'raw')
train_supervised_models(df)
