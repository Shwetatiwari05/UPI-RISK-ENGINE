# %% [markdown]
# # Anomaly Detection
#
# Train Isolation Forest and Local Outlier Factor for unsupervised anomaly scores.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import load_and_map_all
from src.anomaly_detection import train_anomaly_models

# %%
df = load_and_map_all(PROJECT_ROOT / 'data' / 'raw')
train_anomaly_models(df)
