# %% [markdown]
# # Preprocessing
#
# Validate missing value handling, duplicate removal, encoding, and scaling.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import load_and_map_all
from src.data_preprocessing import PreprocessingConfig, UPITransactionPreprocessor

# %%
df = load_and_map_all(PROJECT_ROOT / 'data' / 'raw')
preprocessor = UPITransactionPreprocessor(PreprocessingConfig(scaler='robust', encoder='onehot'))
X, y = preprocessor.fit_transform(df)
X.shape, y.shape
